# %%
import os
import datetime
from PIL import Image, ImageDraw, ImageFont
import pprint
import random

def generate_text_image(width, height, text, font_name, font_color, border_color):
    img = Image.new("RGBA", (width, height), (255, 255, 255, 0))
    draw = ImageDraw.Draw(img)

    font_size = 1
    font = ImageFont.truetype(font_name, font_size)

    while True:
        text_width, text_height = draw.textsize(text, font)
        if text_width < width and text_height < height:
            font_size += 1
            font = ImageFont.truetype(font_name, font_size)
        else:
            break

    font = ImageFont.truetype(font_name, font_size - 1)
    text_width, text_height = draw.textsize(text, font)

    x = (width - text_width) // 2
    y = (height - text_height) // 2

    for border_x in range(-1, 2):
        for border_y in range(-1, 2):
            draw.text((x + border_x, y + border_y), text, font=font, fill=border_color)
    draw.text((x, y), text, font=font, fill=font_color)

    return img

def generate_fonts_dictionary(fonts_directory):
    fonts_available = {}

    for file in os.listdir(fonts_directory):
        if file.endswith(".otf") or file.endswith(".ttf"):
            file_name_without_extension = os.path.splitext(file)[0]
            file_path = os.path.join(fonts_directory, file)
            fonts_available[file_name_without_extension] = file_path

    return fonts_available

fonts_directory = "C:\\Users\\trent\\OneDrive\\Documents\\GitHub\\ai_art_creation\\ai_art_creation\\image_processing\\Fonts"
fonts_available = generate_fonts_dictionary(fonts_directory)
print(len(fonts_available.keys()))
print_list = pprint.PrettyPrinter(width=100, compact=True)
print_list.pprint(fonts_available.keys())

# Usage in your code
font_name = random.choice(list(fonts_available.keys()))

# Example usage
output_path = "C:/Users/trent/OneDrive/Documents/GitHub/ai_art_creation/ai_art_creation/image_processing/images_raw/"
timestamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = f"{timestamp}-font.png"

image = generate_text_image(
    width=1024,
    height=1024,
    text="Hello, World!",
    font_name=fonts_available[font_name],
    font_color=(255, 255, 255, 255),
    border_color=(0, 0, 0, 255)
)

image.save(os.path.join(output_path, filename))
# Out:
# 1886
# ...

# %%
font_library = ['Open Sans', 'Lobster', 'Impact', 'Comfortaa', 'Amatic SC', 'Pacifico', 'Source Sans Pro', 'Playfair Display', 'Lato', 'Oswald', 
                'Catamaran', 'Bangers', 'Raleway', 'Archivo Narrow', 'Indie Flower', 'Anton', 'Tangerine', 'Old Standard TT', 'Righteous', 'Cabin', 
                'Bitter', 'Poppins', 'Montserrat', 'Ubuntu', 'Roboto', 'Bebas Neue', 'Bungee', 'ChunkFive', 'Cooper Hewitt', 'Dosis', 
                'Exo', 'Frutiger', 'Garamond', 'Gill Sans', 'Gotham', 'Helvetica Neue', 'ITC Franklin Gothic', 'Josefin Sans', 'Kabel', 'League Gothic', 
                'Lobster Two', 'Maven Pro', 'Merriweather', 'Neutraface', 'Nexa', 'Norwester', 'Ostrich Sans', 'Pacifico Alternate', 'Panton', 'Proxima Nova', 
                'Raleway Dots', 'Rockwell', 'Sanchez', 'SF Sports Night', 'Signika', 'Sofia Pro', 'Titillium Web', 'Trade Gothic', 'Ubuntu Condensed', 'Ultra', 
                'Uni Sans', 'Varela Round', 'Vollkorn', 'Walkway', 'Yanone Kaffeesatz', 'Zilla Slab', 'Abril Fatface', 'Arvo', 'Barlow Condensed', 'Baumans', 
                'Cooper Black Pro', 'Eames Century Modern', 'Futura PT', 'HVD Comic Serif', 'Klinic Slab', 'Adelle Sans', 'Aileron', 'Akrobat', 'Aleo', 'Apex Sans', 
                'Baloo Tammudu', 'Beon', 'Bodoni XT', 'Brandon Grotesque', 'Century Gothic', 'Clarendon', 'Code Pro', 'Comfortaa Sans', 'Copperplate', 'Couture', 
                'Cutive Mono', 'District Pro', 'FF DIN', 'Franklin Gothic', 'Gidole', 'Hammersmith One', 'Headliner No. 45', 'Jura', 'Kelson Sans', 'Lemon/Milk']

# Convert lists to sets for set operations
fonts_available_keys_set = set(fonts_available.keys())
font_library_set = set(font_library)

# Find the overlap using set intersection
overlap = fonts_available_keys_set.intersection(font_library_set)
print(len(overlap))
print("Overlap:", overlap)

# Find values in font_library but not in fonts_available using set difference
diff = font_library_set.difference(fonts_available_keys_set)
print(len(diff))
print("Values in font_library but not in fonts_available:", diff)
# Out:
# 2
# Overlap: {'Pacifico', 'Lobster'}
# 98
# ...

# %%
import os
import requests
#from ai_art_creation.api.api_key import fonts_api

font_directory = "C:\\Users\\trent\\OneDrive\\Documents\\GitHub\\ai_art_creation\\ai_art_creation\\image_processing\\Fonts"

if not os.path.exists(font_directory):
    os.makedirs(font_directory)

font_library = ['Open Sans', 'Lobster', 'Impact', 'Comfortaa', 'Amatic SC', 'Pacifico', 'Source Sans Pro', 'Playfair Display', 'Lato', 'Oswald', 
                'Catamaran', 'Bangers', 'Raleway', 'Archivo Narrow', 'Indie Flower', 'Anton', 'Tangerine', 'Old Standard TT', 'Righteous', 'Cabin', 
                'Bitter', 'Poppins', 'Montserrat', 'Ubuntu', 'Roboto', 'Bebas Neue', 'Bungee', 'ChunkFive', 'Cooper Hewitt', 'Dosis', 
                'Exo', 'Frutiger', 'Garamond', 'Gill Sans', 'Gotham', 'Helvetica Neue', 'ITC Franklin Gothic', 'Josefin Sans', 'Kabel', 'League Gothic', 
                'Lobster Two', 'Maven Pro', 'Merriweather', 'Neutraface', 'Nexa', 'Norwester', 'Ostrich Sans', 'Pacifico Alternate', 'Panton', 'Proxima Nova', 
                'Raleway Dots', 'Rockwell', 'Sanchez', 'SF Sports Night', 'Signika', 'Sofia Pro', 'Titillium Web', 'Trade Gothic', 'Ubuntu Condensed', 'Ultra', 
                'Uni Sans', 'Varela Round', 'Vollkorn', 'Walkway', 'Yanone Kaffeesatz', 'Zilla Slab', 'Abril Fatface', 'Arvo', 'Barlow Condensed', 'Baumans', 
                'Cooper Black Pro', 'Eames Century Modern', 'Futura PT', 'HVD Comic Serif', 'Klinic Slab', 'Adelle Sans', 'Aileron', 'Akrobat', 'Aleo', 'Apex Sans', 
                'Baloo Tammudu', 'Beon', 'Bodoni XT', 'Brandon Grotesque', 'Century Gothic', 'Clarendon', 'Code Pro', 'Comfortaa Sans', 'Copperplate', 'Couture', 
                'Cutive Mono', 'District Pro', 'FF DIN', 'Franklin Gothic', 'Gidole', 'Hammersmith One', 'Headliner No. 45', 'Jura', 'Kelson Sans', 'Lemon/Milk']

google_fonts_api_key = "AIzaSyBNqJLvi3i4Xb9yNZROHqzWfO1ZMB3ZH78"  # Replace this with your Google Fonts API key
failed_fonts = []

for font_name in font_library:
    try:
        response = requests.get(
            f"https://www.googleapis.com/webfonts/v1/webfonts"
            f"?key={google_fonts_api_key}"
            f"&sort=alpha"
        )
        response.raise_for_status()
        fonts = response.json()["items"]

        font = next((f for f in fonts if f["family"] == font_name), None)

        if font:
            for variant, font_url in font["files"].items():
                font_filename = f"{font_name.replace(' ', '_')}-{variant}.ttf"
                font_response = requests.get(font_url)

                if font_response.status_code == 200:
                    with open(os.path.join(font_directory, font_filename), "wb") as font_file:
                        font_file.write(font_response.content)
                    print(f"Downloaded and saved font: {font_filename}")
                else:
                    print(f"Failed to download font from: {font_url}")
                    failed_fonts.append(font_name)

        else:
            print(f"Font not found: {font_name}")
            failed_fonts.append(font_name)

    except Exception as e:
        print(f"Failed to download font: {font_name}")
        print(f"Error: {e}")
        failed_fonts.append(font_name)
        
print(f"Failed to download fonts: {failed_fonts}")
# Out:
# Downloaded and saved font: Open_Sans-300.ttf
# Downloaded and saved font: Open_Sans-regular.ttf
# Downloaded and saved font: Open_Sans-500.ttf
# Downloaded and saved font: Open_Sans-600.ttf
# Downloaded and saved font: Open_Sans-700.ttf
# Downloaded and saved font: Open_Sans-800.ttf
# Downloaded and saved font: Open_Sans-300italic.ttf
# Downloaded and saved font: Open_Sans-italic.ttf
# Downloaded and saved font: Open_Sans-500italic.ttf
# Downloaded and saved font: Open_Sans-600italic.ttf
# Downloaded and saved font: Open_Sans-700italic.ttf
# Downloaded and saved font: Open_Sans-800italic.ttf
# Downloaded and saved font: Lobster-regular.ttf
# Font not found: Impact
# Downloaded and saved font: Comfortaa-300.ttf
# Downloaded and saved font: Comfortaa-regular.ttf
# Downloaded and saved font: Comfortaa-500.ttf
# Downloaded and saved font: Comfortaa-600.ttf
# Downloaded and saved font: Comfortaa-700.ttf
# Downloaded and saved font: Amatic_SC-regular.ttf
# ...

# %%
import os
import platform
from fontTools.ttLib import TTFont, TTLibError
import pprint

def get_font_name(font_path):
    try:
        font = TTFont(font_path)
        for record in font["name"].names:
            if record.nameID == 4:
                return record.toUnicode()
    except (TTLibError, KeyError):
        print(f"Error processing font: {font_path}")
    return None

if platform.system() == "Windows":
    font_directory = os.path.join(os.environ["WINDIR"], "Fonts")
elif platform.system() == "Darwin":
    font_directory = os.path.expanduser("~/Library/Fonts")
elif platform.system() == "Linux":
    font_directory = "/usr/share/fonts"
else:
    raise ValueError("Unknown platform")

print(font_directory)
installed_fonts = []

for root, _, files in os.walk(font_directory):
    for file in files:
        _, ext = os.path.splitext(file)
        if ext.lower() in [".ttf", ".otf", ".woff", ".woff2", ".eot", ".svg"]:
            font_path = os.path.join(root, file)
            font_name = get_font_name(font_path)
            if font_name:
                installed_fonts.append(font_name)
            else:
                print(f"Could not find font name for: {file}")

print(len(installed_fonts))
print_list = pprint.PrettyPrinter(width=100, compact=True)
print_list.pprint(installed_fonts)
# Out:
# C:\WINDOWS\Fonts
# 341
# ['Agency FB Bold', 'Agency FB', 'Algerian', 'Book Antiqua Bold', 'Book Antiqua Bold Italic',
#  'Book Antiqua Italic', 'Arial', 'Arial Bold', 'Arial Bold Italic', 'Arial Italic', 'Arial Narrow',
#  'Arial Narrow Bold', 'Arial Narrow Bold Italic', 'Arial Narrow Italic', 'Arial Black',
#  'Arial Rounded MT Bold', 'Bahnschrift', 'Baskerville Old Face', 'Bauhaus 93', 'Bell MT',
#  'Bell MT Bold', 'Bell MT Italic', 'Bernard MT Condensed', 'Book Antiqua', 'Bodoni MT Bold',
#  'Bodoni MT Bold Italic', 'Bodoni MT Black Italic', 'Bodoni MT Black', 'Bodoni MT Condensed Bold',
#  'Bodoni MT Condensed Bold Italic', 'Bodoni MT Condensed Italic', 'Bodoni MT Condensed',
#  'Bodoni MT Italic', 'Bodoni MT Poster Compressed', 'Bodoni MT', 'Bookman Old Style',
#  'Bookman Old Style Bold', 'Bookman Old Style Bold Italic', 'Bookman Old Style Italic',
#  'Bradley Hand ITC', 'Britannic Bold', 'Berlin Sans FB Bold', 'Berlin Sans FB Demi Bold',
# ...

# %%
# list fonts not installed on system

import os
import platform
from fontTools.ttLib import TTFont, TTLibError

if platform.system() == "Windows":
    font_directory = os.path.join(os.environ["WINDIR"], "Fonts")
elif platform.system() == "Darwin":
    font_directory = os.path.expanduser("~/Library/Fonts")
elif platform.system() == "Linux":
    font_directory = "/usr/share/fonts"
else:
    raise ValueError("Unknown platform")

installed_fonts = []

for root, _, files in os.walk(font_directory):
    for file in files:
        if file.endswith(".ttf") or file.endswith(".otf"):
            font_path = os.path.join(root, file)
            try:
                font = TTFont(font_path)
                font_name_record = font["name"].getName(4, 3, 1, 0x409)
                if font_name_record:
                    font_name = font_name_record.toUnicode()
                    installed_fonts.append(font_name)
                else:
                    print(f"Could not find font name for: {file}")
            except (TTLibError, KeyError):
                print(f"Error processing font: {file}")

font_library = ['Impact', 'ChunkFive', 'Cooper Hewitt', 'Frutiger', 'Garamond', 'Gill Sans', 'Gotham', 'Helvetica Neue', 'ITC Franklin Gothic', 'Kabel',
                'Neutraface', 'Nexa', 'Norwester', 'Ostrich Sans', 'Pacifico Alternate', 'Panton', 'Proxima Nova', 'Rockwell', 'SF Sports Night', 'Sofia Pro',
                'Trade Gothic', 'Uni Sans', 'Walkway', 'Cooper Black Pro', 'Eames Century Modern', 'Futura PT', 'HVD Comic Serif', 'Klinic Slab', 'Adelle Sans', 'Aileron',
                'Akrobat', 'Apex Sans', 'Baloo Tammudu', 'Beon', 'Bodoni XT', 'Brandon Grotesque', 'Century Gothic', 'Clarendon', 'Code Pro', 'Comfortaa Sans',
                'Copperplate', 'Couture', 'District Pro', 'FF DIN', 'Franklin Gothic', 'Gidole', 'Headliner No. 45', 'Kelson Sans', 'Lemon/Milk']

not_installed_fonts = [font for font in font_library if font not in installed_fonts]

print_list = pprint.PrettyPrinter(width = 100, compact = True)
print_list.pprint(not_installed_fonts)

#print("Fonts not installed:")
#print(not_installed_fonts)
#for font in not_installed_fonts:
#    print(font)
# Out:
# Could not find font name for: marlett.ttf
# Could not find font name for: symbol.ttf
# Could not find font name for: webdings.ttf
# Could not find font name for: wingding.ttf
# ['ChunkFive', 'Cooper Hewitt', 'Frutiger', 'Garamond', 'Gill Sans', 'Gotham', 'Helvetica Neue',
#  'ITC Franklin Gothic', 'Kabel', 'Neutraface', 'Nexa', 'Norwester', 'Ostrich Sans',
#  'Pacifico Alternate', 'Panton', 'Proxima Nova', 'Rockwell', 'SF Sports Night', 'Sofia Pro',
#  'Trade Gothic', 'Uni Sans', 'Walkway', 'Cooper Black Pro', 'Eames Century Modern', 'Futura PT',
#  'HVD Comic Serif', 'Klinic Slab', 'Adelle Sans', 'Aileron', 'Akrobat', 'Apex Sans',
#  'Baloo Tammudu', 'Beon', 'Bodoni XT', 'Brandon Grotesque', 'Century Gothic', 'Clarendon',
#  'Code Pro', 'Comfortaa Sans', 'Copperplate', 'Couture', 'District Pro', 'FF DIN',
#  'Franklin Gothic', 'Gidole', 'Headliner No. 45', 'Kelson Sans', 'Lemon/Milk']

# %%
import os
import platform
from fontTools.ttLib import TTFont, TTLibError
import pprint

def get_font_name(font_path):
    try:
        font = TTFont(font_path)
        for record in font["name"].names:
            if record.nameID == 4:
                return record.toUnicode()
    except (TTLibError, KeyError):
        print(f"Error processing font: {font_path}")
    return None

def get_installed_fonts(font_directory):
    installed_fonts = []

    for root, _, files in os.walk(font_directory):
        for file in files:
            _, ext = os.path.splitext(file)
            if ext.lower() in [".ttf", ".otf", ".woff", ".woff2", ".eot", ".svg"]:
                font_path = os.path.join(root, file)
                font_name = get_font_name(font_path)
                if font_name:
                    installed_fonts.append(font_name)
                else:
                    print(f"Could not find font name for: {file}")

    return installed_fonts

if platform.system() == "Windows":
    font_directory = os.path.join(os.environ["WINDIR"], "Fonts")
elif platform.system() == "Darwin":
    font_directory = os.path.expanduser("~/Library/Fonts")
elif platform.system() == "Linux":
    font_directory = "/usr/share/fonts"
else:
    raise ValueError("Unknown platform")

print("Font directory:", font_directory)
installed_fonts = get_installed_fonts(font_directory)

print(f"Number of installed fonts: {len(installed_fonts)}")
print_list = pprint.PrettyPrinter(width=100, compact=True)
print_list.pprint(installed_fonts)

# Remove fonts that are not installed
for root, _, files in os.walk(font_directory):
    for file in files:
        _, ext = os.path.splitext(file)
        if ext.lower() in [".ttf", ".otf", ".woff", ".woff2", ".eot", ".svg"]:
            font_path = os.path.join(root, file)
            font_name = get_font_name(font_path)
            if font_name:
                if font_name not in installed_fonts:
                    print(f"Font not installed: {font_name} ({file})")
                    try:
                        os.remove(font_path)
                        print(f"Removed font file: {file}")
                    except Exception as e:
                        print(f"Error removing font file {file}: {e}")
            else:
                print(f"Could not find font name for: {file}")
# Out:
# Font directory: C:\WINDOWS\Fonts
# Number of installed fonts: 341
# ['Agency FB Bold', 'Agency FB', 'Algerian', 'Book Antiqua Bold', 'Book Antiqua Bold Italic',
#  'Book Antiqua Italic', 'Arial', 'Arial Bold', 'Arial Bold Italic', 'Arial Italic', 'Arial Narrow',
#  'Arial Narrow Bold', 'Arial Narrow Bold Italic', 'Arial Narrow Italic', 'Arial Black',
#  'Arial Rounded MT Bold', 'Bahnschrift', 'Baskerville Old Face', 'Bauhaus 93', 'Bell MT',
#  'Bell MT Bold', 'Bell MT Italic', 'Bernard MT Condensed', 'Book Antiqua', 'Bodoni MT Bold',
#  'Bodoni MT Bold Italic', 'Bodoni MT Black Italic', 'Bodoni MT Black', 'Bodoni MT Condensed Bold',
#  'Bodoni MT Condensed Bold Italic', 'Bodoni MT Condensed Italic', 'Bodoni MT Condensed',
#  'Bodoni MT Italic', 'Bodoni MT Poster Compressed', 'Bodoni MT', 'Bookman Old Style',
#  'Bookman Old Style Bold', 'Bookman Old Style Bold Italic', 'Bookman Old Style Italic',
# ...

# %%
font_library = ['Open Sans', 'Lobster', 'Impact', 'Comfortaa', 'Amatic SC', 'Pacifico', 'Source Sans Pro', 'Playfair Display', 'Lato', 'Oswald', 
                'Catamaran', 'Bangers', 'Raleway', 'Archivo Narrow', 'Indie Flower', 'Anton', 'Tangerine', 'Old Standard TT', 'Righteous', 'Cabin', 
                'Bitter', 'Poppins', 'Montserrat', 'Ubuntu', 'Roboto', 'Bebas Neue', 'Bungee', 'ChunkFive', 'Cooper Hewitt', 'Dosis', 
                'Exo', 'Frutiger', 'Garamond', 'Gill Sans', 'Gotham', 'Helvetica Neue', 'ITC Franklin Gothic', 'Josefin Sans', 'Kabel', 'League Gothic', 
                'Lobster Two', 'Maven Pro', 'Merriweather', 'Neutraface', 'Nexa', 'Norwester', 'Ostrich Sans', 'Pacifico Alternate', 'Panton', 'Proxima Nova', 
                'Raleway Dots', 'Rockwell', 'Sanchez', 'SF Sports Night', 'Signika', 'Sofia Pro', 'Titillium Web', 'Trade Gothic', 'Ubuntu Condensed', 'Ultra', 
                'Uni Sans', 'Varela Round', 'Vollkorn', 'Walkway', 'Yanone Kaffeesatz', 'Zilla Slab', 'Abril Fatface', 'Arvo', 'Barlow Condensed', 'Baumans', 
                'Cooper Black Pro', 'Eames Century Modern', 'Futura PT', 'HVD Comic Serif', 'Klinic Slab', 'Adelle Sans', 'Aileron', 'Akrobat', 'Aleo', 'Apex Sans', 
                'Baloo Tammudu', 'Beon', 'Bodoni XT', 'Brandon Grotesque', 'Century Gothic', 'Clarendon', 'Code Pro', 'Comfortaa Sans', 'Copperplate', 'Couture', 
                'Cutive Mono', 'District Pro', 'FF DIN', 'Franklin Gothic', 'Gidole', 'Hammersmith One', 'Headliner No. 45', 'Jura', 'Kelson Sans', 'Lemon/Milk']

font_library.sort()
font_library
# Out:
# ['Abril Fatface',
#  'Adelle Sans',
#  'Aileron',
#  'Akrobat',
#  'Aleo',
#  'Amatic SC',
#  'Anton',
#  'Apex Sans',
#  'Archivo Narrow',
#  'Arvo',
#  'Baloo Tammudu',
#  'Bangers',
#  'Barlow Condensed',
#  'Baumans',
#  'Bebas Neue',
#  'Beon',
#  'Bitter',
#  'Bodoni XT',
#  'Brandon Grotesque',
#  'Bungee',
#  'Cabin',
#  'Catamaran',
#  'Century Gothic',
#  'ChunkFive',
#  'Clarendon',
#  'Code Pro',
#  'Comfortaa',
#  'Comfortaa Sans',
#  'Cooper Black Pro',
#  'Cooper Hewitt',
#  'Copperplate',
#  'Couture',
#  'Cutive Mono',
#  'District Pro',
#  'Dosis',
#  'Eames Century Modern',
#  'Exo',
#  'FF DIN',
#  'Franklin Gothic',
#  'Frutiger',
#  'Futura PT',
#  'Garamond',
#  'Gidole',
#  'Gill Sans',
#  'Gotham',
#  'HVD Comic Serif',
#  'Hammersmith One',
#  'Headliner No. 45',
#  'Helvetica Neue',
#  'ITC Franklin Gothic',
#  'Impact',
#  'Indie Flower',
#  'Josefin Sans',
#  'Jura',
#  'Kabel',
#  'Kelson Sans',
#  'Klinic Slab',
#  'Lato',
#  'League Gothic',
# ...
